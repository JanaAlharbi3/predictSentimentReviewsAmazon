# %% [markdown]
# ## **1)Import dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_yelp=pd.read_csv('yelp_labelled.txt',sep='\t',header=None)

# %%
# 1 stands for positive and 0 stands for negative
data_yelp.head()
# Out:
#                                                    0  1
# 0                           Wow... Loved this place.  1
# 1                                 Crust is not good.  0
# 2          Not tasty and the texture was just nasty.  0
# 3  Stopped by during the late May bank holiday of...  1
# 4  The selection on the menu was great and so wer...  1

# %%
data_yelp.tail()
# Out:
#                                                      0  1
# 995  I think food should have flavor and texture an...  0
# 996                           Appetite instantly gone.  0
# 997  Overall I was not impressed and would not go b...  0
# 998  The whole experience was underwhelming, and I ...  0
# 999  Then, as if I hadn't wasted enough of my life ...  0

# %%
# 1000 is rows and 2 is the columns
data_yelp.shape
# Out:
# (1000, 2)

# %%
# as we saw the columns have no header so we assign one
column_name=['Reviews','Sentiment']
data_yelp.columns=column_name

# %%
# now we can see the column's name
data_yelp.head()
# Out:
#                                              Reviews  Sentiment
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
# same for amazon data
data_amazone=pd.read_csv('amazon_cells_labelled.txt',sep='\t')

# %%
data_amazone.head()
# Out:
#   So there is no way for me to plug it in here in the US unless I go by a converter.  \
# 0                        Good case, Excellent value.
# 1                             Great for the jawbone.
# 2  Tied to charger for conversations lasting more...
# 3                                  The mic is great.
# 4  I have to jiggle the plug to get it to line up...
#
#    0
# 0  1
# 1  1
# 2  0
# 3  1
# 4  0

# %%
amazon_columns=['Reviews','Sentiment']
data_amazone.columns=amazon_columns

# %%
data_amazone.head()
# Out:
#                                              Reviews  Sentiment
# 0                        Good case, Excellent value.          1
# 1                             Great for the jawbone.          1
# 2  Tied to charger for conversations lasting more...          0
# 3                                  The mic is great.          1
# 4  I have to jiggle the plug to get it to line up...          0

# %%
data_amazone.shape
# Out:
# (999, 2)

# %%
# same for IMDB data
data_IMDB=pd.read_csv('imdb_labelled.txt',sep='\t')

# %%
data_IMDB.head()
# Out:
#   A very, very, very slow-moving, aimless movie about a distressed, drifting young man.    \
# 0  Not sure who was more lost - the flat characte...
# 1  Attempting artiness with black & white and cle...
# 2       Very little music or anything to speak of.
# 3  The best scene in the movie was when Gerardo i...
# 4  The rest of the movie lacks art, charm, meanin...
#
#    0
# 0  0
# 1  0
# 2  0
# 3  1
# 4  0

# %%
column_imdb=['Reviews','Sentiment']
data_IMDB.columns=column_imdb

# %%
data_IMDB.head()
# Out:
#                                              Reviews  Sentiment
# 0  Not sure who was more lost - the flat characte...          0
# 1  Attempting artiness with black & white and cle...          0
# 2       Very little music or anything to speak of.            0
# 3  The best scene in the movie was when Gerardo i...          1
# 4  The rest of the movie lacks art, charm, meanin...          0

# %%
# now we append them
data=[]
data=data_yelp.append([data_amazone,data_IMDB],ignore_index=True)
# Out:
# <ipython-input-28-3fe185f4758a>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data_yelp.append([data_amazone,data_IMDB],ignore_index=True)

# %%
data.shape
# Out:
# (2746, 2)

# %%
data.columns
# Out:
# Index(['Reviews', 'Sentiment'], dtype='object')

# %%
data.head()
# Out:
#                                              Reviews  Sentiment
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
# labelled by sentiment which mean supervised
data['Sentiment'].value_counts()
# Out:
# 1    1386
# 0    1360
# Name: Sentiment, dtype: int64

# %%
# cheack for missing(null) values same as data.isnull().sum()
data.isna().sum()
# Out:
# Reviews      0
# Sentiment    0
# dtype: int64

# %%
# cheack for null(missing) values same as data.isna().sum()
data.isnull().sum()
# Out:
# Reviews      0
# Sentiment    0
# dtype: int64

# %%
x=data['Reviews']
y=data['Sentiment']

# %% [markdown]
# # **2)Data cleaning**

# %%
import string

# %%
punc=string.punctuation

# %%
punc
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from spacy.lang.en.stop_words import STOP_WORDS
# list of stop words
stopwords=list(STOP_WORDS)

# %%
stopwords
# Out:
# ['these',
#  'one',
#  'the',
#  'ourselves',
#  'besides',
#  'become',
#  'else',
#  'mine',
#  'whole',
#  'what',
#  'below',
#  'ever',
#  'via',
#  'noone',
#  'by',
#  'using',
#  'wherein',
#  'throughout',
#  'above',
#  'onto',
#  'serious',
#  'while',
#  'which',
#  'least',
#  'still',
#  "'m",
#  'formerly',
#  'beside',
#  'with',
#  'becomes',
#  'namely',
#  'upon',
#  'wherever',
#  'nobody',
#  'would',
#  'is',
#  'i',
#  'nowhere',
#  'she',
#  'take',
#  'already',
#  '‘ve',
#  'us',
#  'too',
#  'more',
#  'former',
#  'meanwhile',
#  'we',
#  'behind',
#  'empty',
#  'much',
#  "'re",
#  'along',
#  'now',
#  'yourself',
#  'against',
#  '’ve',
#  'both',
#  'every',
#  'move',
#  'anyway',
#  'into',
#  'on',
#  'across',
#  'thereby',
#  'through',
#  'therefore',
#  'amongst',
#  'call',
#  'from',
#  'he',
#  'whereas',
#  'seem',
#  'them',
#  'you',
#  'whereafter',
#  'became',
#  '’d',
#  'own',
#  'quite',
#  'of',
#  'will',
#  'whoever',
#  'side',
# ...

# %%
# creating function for data cleaning
import spacy
nlp = spacy.load(name = 'en_core_web_sm')
def text_data_cleaning(sentence):
  doc=nlp(sentence)

  tokens=[]
  for token in doc:
    # most non-pronoun words benefit from lemmatization. Converting the word to its lemma form, making it lowercase, and stripping any extra spaces helps in standardizing the text data.
        if token.lemma_ != "-PRON-":
            temp = token.lemma_.lower().strip()
        else:
          # Pronouns, however, are already fairly standardized and converting them to their lemma form might not be necessary or might even be undesirable depending on the context.
            temp = token.lower_
        tokens.append(temp)

  cleaned_tokens=[]
  for token in tokens:
    if token not in stopwords and token not in punc:
      cleaned_tokens.append(token)

  return cleaned_tokens  # Return statement outside the loops

# %%
text_data_cleaning("Hello all, It's a beautiful day!")
# Out:
# ['hello', 'beautiful', 'day']

# %% [markdown]
# ## **Vectorisation feature engineering (TF-IDF)**

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

# %%
# to convert all our data to numbers, but before we convert them to number we must clean them first by text_data_cleaning function
tfidf=TfidfVectorizer(tokenizer=text_data_cleaning)

# %%
# LinearSVC is a type of Support Vector Machine (SVM) classifier specifically designed for linear classification tasks
classifier=LinearSVC()

# %% [markdown]
# # 3)TrainData

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((2196,), (550,))

# %%
x_train.head
# Out:
# <bound method NDFrame.head of 2321    Watching washing machine twirling around would...
# 526                          And it was way to expensive.
# 1509    This frog phone charm is adorable and very eye...
# 144     Nice blanket of moz over top but i feel like t...
# 2482    Kris Kristoffersen is good in this movie and r...
#                               ...
# 763                       But the service was beyond bad.
# 835     I paid the bill but did not tip because I felt...
# 1653    The charger arrived within the promised timefr...
# 2607    Editing: The editing of this film was phenomen...
# 2732                      ;) Recommend with confidence!
# Name: Reviews, Length: 2196, dtype: object>

# %%
# pipline object first will do vactorization then classification
clf=Pipeline([('tfidf',tfidf),('clf',classifier)])

# %%
# now clf will clean the data and convert them to numbers since it is the pipline object
clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(tokenizer=<function text_data_cleaning at 0x7a47e68eb010>)),
#                 ('clf', LinearSVC())])

# %% [markdown]
# # 4)Predict

# %%
from sklearn.metrics import accuracy_score

# %%
y_predict=clf.predict(x_test)

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.7636363636363637

# %%
# since it is pipline we can try the model on what we write of reviews , we don’t need to do cleaning again
clf.predict(['it is great service i like it '])
# Out:
# array([1])

# %%
clf.predict(['shame on you! '])
# Out:
# array([0])
